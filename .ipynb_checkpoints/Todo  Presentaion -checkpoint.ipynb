# %%
#Defining Empty List
work=[]
print('===== Welcome =====')
#All Fuctions---------------------------------
            
                #Main Menu
def menu():
    
    print('\n 1: View your TODO list\n 2: Add item \n 3: Update item \n 4: Delete item \n 5: Eixt \n ')
    

                #CheckingInput

def check(inp):
    try:
        if int(inp) and int(inp)>0 and int(inp)<=5:
            return True
        else:
            return False

        
    except ValueError:
        return False
    
    
                #Viewing Your List
    
def view():
    print('=====Your List====')
    if len(work)==0:
        print('\nNo items added uptill now\n')
    else:
        for i in range(0,lim):
            print(i+1,work[i])
            
            #Adding to your list
def Additem():
    add=input('Enter your work \n this will be added in your TODO list ')
    date =input("\nEnter the date todo this task ")
    time = input("\nEnter time todo this task ")
    
    
    work.append({add:{'date':date,'Time':time}})
    lim=len(work)
    print('====Task Added===\n')
    
            #Update
def Updated(update):
    add=input('Enter your work \nthis will be added in your TODO list ')
    date =input("Enter the date todo this task ")
    time = input("Enter time todo this task ")
    work[update-1]={add:{'date':date,'Time':time}}
    print('=======Updated=======')
    
    
        #Delete
def _delete():
    global work
    print('which record u want to delete\npress 0 to delete all')
    lim=len(work)
    for i in range(0,lim):
        print(i+1,work[i])
    target = int(input('enter index'))
    if target !=0:
        del work[target-1]
        lim=len(work)
        for i in range(0,lim):
            print(i+1,work[i])
    else:
        del work
        print ('No Todo items added right now')
        


#---------------------------------------------

#Body

while True:
    lim = len(work)
    menu()
    userInput = input('Please Enter your input\n eg 1 , 2 ,3 ,4 ,5\n')
    if check(userInput)==True:
        
        if int(userInput)==5:
            print('\n------------------Thankyou----------')
            break
        elif int(userInput)==1:
            view()
        elif int(userInput)==2:
            Additem()
        elif int(userInput)==3:
            print('which record you want to update?\n')
            for i in range(0,lim):
                print(i+1,work[i])
            update=int(input('Enter number pls '))
            Updated(update)
        elif int(userInput)==4:
            _delete()
                    
        
    elif check(userInput)==False:
        print('invalid input')
# Out:
# ===== Welcome =====
#
#  1: View your TODO list
#  2: Add item
#  3: Update item
#  4: Delete item
#  5: Eixt
#
# Please Enter your input
#  eg 1 , 2 ,3 ,4 ,5
# 1
# =====Your List====
#
# No items added uptill now
#
#
#  1: View your TODO list
#  2: Add item
#  3: Update item
#  4: Delete item
#  5: Eixt
#
# Please Enter your input
#  eg 1 , 2 ,3 ,4 ,5
# 2
# Enter your work
#  this will be added in your TODO list match
#
# Enter the date todo this task 9 dec
#
# Enter time todo this task 9pm
# ====Task Added===
#
#
#  1: View your TODO list
#  2: Add item
#  3: Update item
#  4: Delete item
#  5: Eixt
#
# Please Enter your input
#  eg 1 , 2 ,3 ,4 ,5
# 2
# Enter your work
#  this will be added in your TODO list presentation
#
# Enter the date todo this task 10 dec
#
# Enter time todo this task 10pm
# ====Task Added===
#
#
#  1: View your TODO list
#  2: Add item
#  3: Update item
#  4: Delete item
#  5: Eixt
#
# Please Enter your input
#  eg 1 , 2 ,3 ,4 ,5
# 2
# Enter your work
# ...
