# %%
#TODO APP
work=[{"Nothing":{"Nothing":'Nothing'}}]
#All fuctions
def Additem():
    add=input('Enter your work /n this will be added in your TODO list ')
    date =input("Enter the date todo this task ")
    time = input("Enter time todo this task ")
    
    
    work.append({add:{'date':date,'Time':time}})
    lim=len(work)
    for i in range(0,lim):
        print(i+1,work[i])
       
    
def Updated(update):
    add=input('Enter your work /n this will be added in your TODO list ')
    date =input("Enter the date todo this task ")
    time = input("Enter time todo this task ")
    work[update-1]={add:{'date':date,'Time':time}}
    
    for i in range(0,lim):
        print(i+1,work[i])
        
def _delete():
    global work
    print('which record u want to delte or press zero to delete all')
    lim=len(work)
    for i in range(0,lim):
        print(i+1,work[i])
    target = int(input('enter index'))
    if target !=0:
        del work[target-1]
        lim=len(work)
        for i in range(0,lim):
            print(i+1,work[i])
    else:
        del work
        print ('No Todo items added right now')

        
name=input(' Enter Your Name')
print("===============Welcocome"+ " "+name+"=======================")
#Body
for z in range(0,10):
        lim=len(work)
        guide= input('Press 1 to see your list or Press 2 to Add or delete in your list ')
        #Only Printing list
        if int(guide)==1:
            lim=len(work)
            for i in range(0,lim):
                print(i+1,work[i])

        #Add Update and Delete
        elif int(guide)==2:
            opt=int(input("Press 1 to add , Press 2 to Update , Press 3 to Delete"))
            if opt==1:
                Additem()
            elif opt == 2:
                print('which record you want to update?')
                for i in range(0,lim):
                    print(i+1,work[i])
                update=int(input('Enter number pls '))
                Updated(update)
                
            elif opt==3:
                _delete()
# Out:
#  Enter Your NameMuzzammil
# ===============Welcocome Muzzammil=======================
# Press 1 to see your list or Press 2 to Add or delete in your list 2
# Press 1 to add , Press 2 to Update , Press 3 to Delete1
# Enter your work /n this will be added in your TODO list SMIT Meeting
# Enter the date todo this task 10 dec
# Enter time todo this task 8 30
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 2
# Press 1 to add , Press 2 to Update , Press 3 to Delete1
# Enter your work /n this will be added in your TODO list Match
# Enter the date todo this task 10 dec
# Enter time todo this task 10pm
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Match': {'date': '10 dec', 'Time': '10pm'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 1
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Match': {'date': '10 dec', 'Time': '10pm'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 2
# Press 1 to add , Press 2 to Update , Press 3 to Delete2
# which record you want to update?
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Match': {'date': '10 dec', 'Time': '10pm'}}
# Enter number pls 3
# Enter your work /n this will be added in your TODO list Python
# Enter the date todo this task 10 dec
# Enter time todo this task 10
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 2
# Press 1 to add , Press 2 to Update , Press 3 to Delete1
# Enter your work /n this will be added in your TODO list Football match
# Enter the date todo this task 11 dec
# Enter time todo this task 8 am
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# 4 {'Football match': {'date': '11 dec', 'Time': '8 am'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 1
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# 4 {'Football match': {'date': '11 dec', 'Time': '8 am'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 2
# Press 1 to add , Press 2 to Update , Press 3 to Delete1
# Enter your work /n this will be added in your TODO list Computer class
# Enter the date todo this task 12 dec
# Enter time todo this task 5pm
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# 4 {'Football match': {'date': '11 dec', 'Time': '8 am'}}
# 5 {'Computer class': {'date': '12 dec ', 'Time': '5pm'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 2
# Press 1 to add , Press 2 to Update , Press 3 to Delete2
# which record you want to update?
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# 4 {'Football match': {'date': '11 dec', 'Time': '8 am'}}
# 5 {'Computer class': {'date': '12 dec ', 'Time': '5pm'}}
# Enter number pls 4
# Enter your work /n this will be added in your TODO list Football match
# Enter the date todo this task 12 dec
# Enter time todo this task 10am
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# 4 {'Football match ': {'date': '12 dec', 'Time': '10am'}}
# 5 {'Computer class': {'date': '12 dec ', 'Time': '5pm'}}
# Press 1 to see your list or Press 2 to Add or delete in your list 2
# Press 1 to add , Press 2 to Update , Press 3 to Delete3
# which record u want to delte or press zero to delete all
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# 4 {'Football match ': {'date': '12 dec', 'Time': '10am'}}
# 5 {'Computer class': {'date': '12 dec ', 'Time': '5pm'}}
# enter index4
# 1 {'Nothing': {'Nothing': 'Nothing'}}
# 2 {'SMIT Meeting': {'date': '10 dec', 'Time': '8 30'}}
# 3 {'Python ': {'date': '10 dec', 'Time': '10'}}
# 4 {'Computer class': {'date': '12 dec ', 'Time': '5pm'}}
